# %%
import pandas as pd
import re
import string

# %%
df = pd.read_csv('../data/Crime_Reports_20260402.csv')

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
# normalize the text data
def normalize_text(text):
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 109214 entries, 0 to 109213
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   File Number              109214 non-null  str
#  1   Date of Report           109214 non-null  str
#  2   Crime Date Time          109193 non-null  str
#  3   Crime                    109214 non-null  str
#  4   Reporting Area           109209 non-null  float64
#  5   Neighborhood             109209 non-null  str
#  6   Location                 108916 non-null  str
#  7   Reporting Area Lat       109209 non-null  float64
#  8   Reporting Area Lon       109209 non-null  float64
#  9   Reporting Area Location  109209 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 8.3 MB

# %%
df.tail()
# Out:
#        File Number           Date of Report  \
# 109209  2025-01746  2025 Feb 27 03:03:00 PM
# 109210  2026-00462  2026 Jan 16 05:40:00 PM
# 109211  2013-04280  2013 Jun 14 09:54:00 PM
# 109212  2025-06645  2025 Jul 22 11:12:00 AM
# 109213  2025-02327  2025 Mar 18 02:57:00 AM
#
#                             Crime Date Time                   Crime  \
# 109209                     02/27/2025 15:02             Hit and Run
# 109210             01/16/2026 12:00 - 17:40     Larceny from Person
# 109211                     06/14/2013 21:53          Warrant Arrest
# 109212  07/12/2025 09:50 - 07/13/2025 12:00  Larceny from Residence
# 109213                     03/18/2025 02:57      Aggravated Assault
#
#         Reporting Area    Neighborhood  \
# 109209           509.0   Cambridgeport
# 109210           502.0   Cambridgeport
# 109211           106.0  East Cambridge
# 109212           607.0   Mid-Cambridge
# 109213           508.0   Cambridgeport
#
#                                         Location  Reporting Area Lat  \
# 109209  Brookline St & Granite St, Cambridge, MA             42.3569
# 109210              200 Albany St, Cambridge, MA             42.3599
# 109211               0 Lambert St, Cambridge, MA             42.3699
# 109212             400 Harvard St, Cambridge, MA             42.3719
# 109213            100 Chestnut St, Cambridge, MA             42.3592
#
#         Reporting Area Lon           Reporting Area Location
# 109209            -71.1124  POINT (-71.11235726 42.35694466)
# 109210            -71.1013  POINT (-71.10125383 42.35985514)
# 109211            -71.0879  POINT (-71.08788275 42.36994454)
# 109212            -71.1121  POINT (-71.11208152 42.37194572)
# 109213            -71.1098  POINT (-71.10983671 42.35922168)
